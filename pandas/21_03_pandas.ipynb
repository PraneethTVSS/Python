# %% [markdown]
# pandas.DataFrame.count — counts the number of non-null values in each DataFrame column.
# pandas.DataFrame.max — finds the highest value in each column.
# pandas.DataFrame.min — finds the lowest value in each column.
# pandas.DataFrame.median — finds the median of each column.
# pandas.DataFrame.std — finds the standard deviation of each column.

# %%
import numpy as np
import pandas as pd

s1 = pd.Series(['Java', 'Manual Testing'])
s2 = pd.Series(['Python', 'Selenium'])
df = pd.DataFrame([s1, s2])
df
# Out:
#         0               1
# 0    Java  Manual Testing
# 1  Python        Selenium

# %%
df = pd.DataFrame([s1, s2], index=['row1', 'row2'])
df
# Out:
#            0               1
# row1    Java  Manual Testing
# row2  Python        Selenium

# %%
# Why this happened ?
df = pd.DataFrame([s1, s2], index=['row1', 'row2'], columns=['col1', 'col2'])
df
# Out:
#       col1  col2
# row1   NaN   NaN
# row2   NaN   NaN

# %%
reviews_df = pd.read_csv('ign.csv')
reviews_df = reviews_df.head()
print(reviews_df['score'].mean())
print('-' * 110)
print(reviews_df.mean())
print('-' * 110)
print(reviews_df.mean(axis=1))
print('-' * 110)
# Out:
# 8.7
# --------------------------------------------------------------------------------------------------------------
# Unnamed: 0          2.0
# score               8.7
# release_year     2012.0
# release_month       9.0
# release_day        11.6
# dtype: float64
# --------------------------------------------------------------------------------------------------------------
# 0    408.4
# 1    408.6
# 2    408.7
# 3    408.7
# 4    408.9
# dtype: float64
# --------------------------------------------------------------------------------------------------------------

# %%
# Arithmetic operations
reviews_df['score']/2
# Out:
# 0    4.50
# 1    4.50
# 2    4.25
# 3    4.25
# 4    4.25
# Name: score, dtype: float64

# %%
result = reviews_df['score'] > 8.8
result
reviews_df[result] # Fancy Indexing
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 7               7      Amazing
# 13             13      Amazing
# 14             14      Amazing
# 24             24      Amazing
# 26             26      Amazing
# 30             30      Amazing
# 33             33      Amazing
# 35             35      Amazing
# 37             37      Amazing
# 38             38      Amazing
# 39             39      Amazing
# 45             45      Amazing
# 50             50      Amazing
# 52             52      Amazing
# 54             54      Amazing
# 57             57      Amazing
# 58             58      Amazing
# 60             60      Amazing
# 61             61      Amazing
# 75             75      Amazing
# 76             76      Amazing
# 77             77      Amazing
# 84             84      Amazing
# 86             86      Amazing
# 87             87      Amazing
# 98             98      Amazing
# 108           108      Amazing
# ...

# %%
reviews_df = pd.read_csv('ign.csv')
filter_reviews = (reviews_df['score'] > 7) & (reviews_df['platform'] == 'Xbox One')
filter_reviews
reviews_df[filter_reviews]
# Out:
#        Unnamed: 0 score_phrase  \
# 17137       17137      Amazing
# 17197       17197      Amazing
# 17295       17295      Amazing
# 17313       17313        Great
# 17317       17317        Great
# 17328       17328        Great
# 17335       17335         Good
# 17358       17358        Great
# 17361       17361        Great
# 17367       17367        Great
# 17391       17391        Great
# 17393       17393        Great
# 17445       17445      Amazing
# 17451       17451      Amazing
# 17463       17463        Great
# 17487       17487         Good
# 17501       17501      Amazing
# 17537       17537         Good
# 17594       17594         Good
# 17610       17610        Great
# 17622       17622        Great
# 17624       17624        Great
# 17629       17629         Good
# 17675       17675      Amazing
# 17703       17703        Great
# 17720       17720         Good
# 17750       17750      Amazing
# 17767       17767        Great
# 17780       17780         Good
# ...

# %%
xbox_reviews = reviews_df[reviews_df['platform'] == 'Xbox One']
xbox_reviews['score'].plot(kind = 'hist')

# %%
ps4_reviews = reviews_df[reviews_df['platform'] == 'PlayStation 4']
ps4_reviews['score'].plot(kind = 'hist')

# %%
ps4_reviews_gt7 = reviews_df[(reviews_df['platform'] == 'PlayStation 4') & (reviews_df['score'] > 7)]
ps4_reviews_gt7['score'].plot(kind = 'hist')

# %%
xbox_reviews_gt7 = reviews_df[(reviews_df['platform'] == 'Xbox One') & (reviews_df['score'] > 7)]
xbox_reviews_gt7['score'].plot(kind = 'hist')

# %%
## Assignment/Exercise
nyc_weather = pd.read_csv('nyc_weather.csv')
nyc_weather
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
# What was the maximum temparature in new york in the month of january?
max_temp = nyc_weather['Temperature'].max()
print(max_temp)
print('-' * 110)
# On which days did it rains?
rains = nyc_weather[nyc_weather['Events'] == 'Rain']
print(rains['EST'])
print('-' * 110)
# What was the average speed of wind during the month?
print(nyc_weather['WindSpeedMPH'].mean())
# Out:
# 50
# --------------------------------------------------------------------------------------------------------------
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object
# --------------------------------------------------------------------------------------------------------------
# 6.892857142857143

# %%
## Read excel
csv_df = pd.read_csv('weather_data.csv')
csv_df
excel_df = pd.read_excel('weather_data.xlsx')
excel_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
csv_df.to_csv('weather_data_op.csv', index=False)
excel_df.to_excel('weather_data_op.xlsx', index=False, sheet_name='weather')

# %%
df = pd.read_csv('weather_data_cities.csv')
g = df.groupby('city')
g

# %%
for city_grp in g:
    print(city_grp)
# Out:
# ('mumbai',         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain)
# ('new york',         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny)
# ('paris',          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy)

# %%
for city, city_grp in g:
    print(city)
    print(city_grp)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group('new york')
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
india_weather = pd.DataFrame({
    "cities": ['blr', 'mumbai', 'hyd'],
    'weather': [24, 56, 78],
    'humidity': [100, 324, 543]
})
us_weather = pd.DataFrame({
    'cities': ['canada', 'texas', 'chicago'],
    'weather': [2, 3, 4],
    'humidity': [34, 545, 67]
})
new_df = pd.concat([india_weather, us_weather])
print(new_df)
print('-' * 110)

new_df = pd.concat([india_weather, us_weather], ignore_index=True)
print(new_df)
print('-' * 110)

new_df = pd.concat([india_weather, us_weather], axis=1)
print(new_df)
# Out:
#     cities  weather  humidity
# 0      blr       24       100
# 1   mumbai       56       324
# 2      hyd       78       543
# 0   canada        2        34
# 1    texas        3       545
# 2  chicago        4        67
# --------------------------------------------------------------------------------------------------------------
#     cities  weather  humidity
# 0      blr       24       100
# 1   mumbai       56       324
# 2      hyd       78       543
# 3   canada        2        34
# 4    texas        3       545
# 5  chicago        4        67
# --------------------------------------------------------------------------------------------------------------
#    cities  weather  humidity   cities  weather  humidity
# 0     blr       24       100   canada        2        34
# 1  mumbai       56       324    texas        3       545
# 2     hyd       78       543  chicago        4        67
